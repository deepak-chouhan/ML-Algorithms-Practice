# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x = [np.random.rand() for i in range(10000)]

# %%
x[:10]
# Out:
# [0.4222708797562492,
#  0.36254553678797485,
#  0.6000198304701494,
#  0.4700611328623907,
#  0.3328930312383347,
#  0.8271416791785653,
#  0.5169138424282013,
#  0.3545900686585606,
#  0.471778269229422,
#  0.45764017132428125]

# %%
plt.hist(np.arctan(x), bins=100);

# %%
x_data = np.linspace(0, 10, 100)
fig, ax = plt.subplots()
ax.scatter(x_data, np.sin(x_data));

# %%
fig, ax = plt.subplots()
ax.hist(np.random.randn(100000), bins=400);

# %%
plt.hist2d(np.random.randn(10000), np.arctan(np.random.randn(10000)), bins=80);
